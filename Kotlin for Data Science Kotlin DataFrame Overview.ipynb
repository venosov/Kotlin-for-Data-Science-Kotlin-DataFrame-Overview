// %%
%use dataframe
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@d6467c1389bc031958acd5310fce39167b5cc581/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
// ...

// %%
%trackExecution

// %%
val df = DataFrame.readCSV("titanic.csv")
df
// Out:
// Executing:
// val df = DataFrame.readCSV("titanic.csv")
// df
// Executing:
// @DataSchema(isOpen = false)
// interface _DataFrameType
//
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType>.`home dest`: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String?> @JvmName("_DataFrameType_home dest") get() = this["home.dest"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String?>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType>.`home dest`: kotlin.String? @JvmName("_DataFrameType_home dest") get() = this["home.dest"] as kotlin.String?
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType>.age: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double?> @JvmName("_DataFrameType_age") get() = this["age"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double?>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType>.age: kotlin.Double? @JvmName("_DataFrameType_age") get() = this["age"] as kotlin.Double?
// ...

// %%
df[5]
// Out:
// Executing:
// df[5]
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-486539263"></table>
//
// <p>DataRow: index = 5, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"pclass: Int\">pclass</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// { name: "<span title=\"survived: Int\">survived</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// { name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["Anderson, Mr. Harry"] },
// { name: "<span title=\"sex: String\">sex</span>", children: [], rightAlign: false, values: ["male"] },
// ...

// %%
df[5..10]
// Out:
// Executing:
// df[5..10]
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-486539262"></table>
//
// <p>DataFrame: rowsCount = 6, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"pclass: Int\">pclass</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// ...

// %%
df.head()
// Out:
// Executing:
// df.head()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-486539261"></table>
//
// <p>DataFrame: rowsCount = 5, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"pclass: Int\">pclass</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// ...

// %%
df.tail()
// Out:
// Executing:
// df.tail()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-486539260"></table>
//
// <p>DataFrame: rowsCount = 5, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"pclass: Int\">pclass</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>"] },
// ...

// %%
df.take(10)
// Out:
// Executing:
// df.take(10)
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-486539259"></table>
//
// <p>DataFrame: rowsCount = 10, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df["name"]
// Out:
// Executing:
// df["name"]
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1979711489"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataColumn: name = "name", type = String, size = 1309</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df["name"][0]
// Out:
// Executing:
// df["name"][0]
// Allen, Miss. Elisabeth Walton

// %%
(df["name"][0] as String).substring(7)
// Out:
// Executing:
// (df["name"][0] as String).substring(7)
// Miss. Elisabeth Walton

// %%
df.name
// Out:
// Executing:
// df.name
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1979711490"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataColumn: name = "name", type = String, size = 1309</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.name[0]
// Out:
// Executing:
// df.name[0]
// Allen, Miss. Elisabeth Walton

// %%
df.name[0].substring(7)
// Out:
// Executing:
// df.name[0].substring(7)
// Miss. Elisabeth Walton

// %%
df[0]
// Out:
// Executing:
// df[0]
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1979711491"></table>
//
// <p>DataRow: index = 0, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"pclass: Int\">pclass</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// { name: "<span title=\"survived: Int\">survived</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// { name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["Allen, Miss. Elisabeth Walton"] },
// ...

// %%
df[0].name
// Out:
// Executing:
// df[0].name
// Allen, Miss. Elisabeth Walton

// %%
df[0].name.substring(7)
// Out:
// Executing:
// df[0].name.substring(7)
// Miss. Elisabeth Walton

// %%
df.schema()
// Out:
// Executing:
// df.schema()
// pclass: Int
// survived: Int
// name: String
// sex: String
// age: Double?
// sibsp: Int
// parch: Int
// ticket: String
// fare: Double?
// cabin: String?
// embarked: String?
// boat: String?
// body: Int?
// home.dest: String?

// %%
df.age.hasNulls()
// Out:
// Executing:
// df.age.hasNulls()
// true

// %%
df.age[0] + 1
// Out:
// Executing:
// df.age[0] + 1
// Line_141.jupyter-kts (1:11 - 12) Operator call corresponds to a dot-qualified call 'df.age[0].plus(1)' which is not allowed on a nullable receiver 'df.age[0]'.

// %%
df.take(10).schema()
// Out:
// Executing:
// df.take(10).schema()
// pclass: Int
// survived: Int
// name: String
// sex: String
// age: Double
// sibsp: Int
// parch: Int
// ticket: String
// fare: Double
// cabin: String?
// embarked: String
// boat: String?
// body: Int?
// home.dest: String

// %%
val top = df.take(10)
// Out:
// Executing:
// val top = df.take(10)
// Executing:
// @DataSchema(isOpen = false)
// interface _DataFrameType1 : Line_5._DataFrameType
//
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType1>.`home dest`: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String> @JvmName("_DataFrameType1_home dest") get() = this["home.dest"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType1>.`home dest`: kotlin.String @JvmName("_DataFrameType1_home dest") get() = this["home.dest"] as kotlin.String
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType1>.age: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double> @JvmName("_DataFrameType1_age") get() = this["age"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType1>.age: kotlin.Double @JvmName("_DataFrameType1_age") get() = this["age"] as kotlin.Double
// ...

// %%
top.age.hasNulls()
// Out:
// Executing:
// top.age.hasNulls()
// false

// %%
top.age[0] + 1
// Out:
// Executing:
// top.age[0] + 1
// 30.0

// %%
df.columnsCount()
// Out:
// Executing:
// df.columnsCount()
// 14

// %%
df.rowsCount()
// Out:
// Executing:
// df.rowsCount()
// 1309

// %%
df.columnNames()
// Out:
// Executing:
// df.columnNames()
// [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]

// %%
df.columnTypes()
// Out:
// Executing:
// df.columnTypes()
// [kotlin.Int, kotlin.Int, kotlin.String, kotlin.String, kotlin.Double?, kotlin.Int, kotlin.Int, kotlin.String, kotlin.Double?, kotlin.String?, kotlin.String?, kotlin.String?, kotlin.Int?, kotlin.String?]

// %%
df.describe()
// Out:
// Executing:
// df.describe()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073473"></table>
//
// <p>DataFrame: rowsCount = 14, columnsCount = 12</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["pclass","survived","name","sex","age","sibsp","parch","ticket","fare","cabin","embarked","boat","body","home.dest"] },
// { name: "<span title=\"type: Any\">type</span>", children: [], rightAlign: false, values: ["Int","Int","String","String","Double","Int","Int","String","Double","String","String","String","Int","String"] },
// ...

// %%
df.select { survived and name and age }
// Out:
// Executing:
// df.select { survived and name and age }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073474"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { survived named "alive" and name and age }
// Out:
// Executing:
// df.select { survived named "alive" and name and age }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073475"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { survived .. age }
// Out:
// Executing:
// df.select { survived .. age }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073476"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 4</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { cols(3,5,6) }
// Out:
// Executing:
// df.select { cols(3,5,6) }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073477"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"sex: String\">sex</span>", children: [], rightAlign: false, values: ["female","male","female","male","female","male","female","male","female","male","male","female","female","female","male","male","male","female","female","male"] },
// ...

// %%
df.select { cols(3..6) }
// Out:
// Executing:
// df.select { cols(3..6) }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073478"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 4</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"sex: String\">sex</span>", children: [], rightAlign: false, values: ["female","male","female","male","female","male","female","male","female","male","male","female","female","female","male","male","male","female","female","male"] },
// ...

// %%
df.select { startsWith("b") }
// Out:
// Executing:
// df.select { startsWith("b") }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073479"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { colsOf<String>() }
// Out:
// Executing:
// df.select { colsOf<String>() }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073480"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { colsOf<String?>() }
// Out:
// Executing:
// df.select { colsOf<String?>() }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073481"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 7</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { cols { it.hasNulls() } }
// Out:
// Executing:
// df.select { cols { it.hasNulls() } }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073482"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 7</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { cols { it.hasNulls() } except age  }
// Out:
// Executing:
// df.select { cols { it.hasNulls() } except age  }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073483"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 6</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { cols { it.hasNulls() } except {age and boat}  }
// Out:
// Executing:
// df.select { cols { it.hasNulls() } except {age and boat}  }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073484"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 5</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.select { cols { it.hasNulls() } except {age and colsOf<String?>() } }
// Out:
// Executing:
// df.select { cols { it.hasNulls() } except {age and colsOf<String?>() } }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1124073485"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.max { age }
// Out:
// Executing:
// df.max { age }
// 705.0

// %%
df.max { age and fare }
// Out:
// Executing:
// df.max { age and fare }
// 5123292.0

// %%
df.maxFor { age and fare }
// Out:
// Executing:
// df.maxFor { age and fare }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1761607681"></table>
//
// <p>DataRow: index = 0, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"age: Double\">age</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">705,0</span></span>"] },
// { name: "<span title=\"fare: Double\">fare</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">5123292,0</span></span>"] },
// ], id: 1761607681, rootId: 1761607681, totalRows: 1 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(1761607681) });
//
//
//         </script>
//         </html>

// %%
df.meanFor { age and fare }
// Out:
// Executing:
// df.meanFor { age and fare }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1761607682"></table>
//
// <p>DataRow: index = 0, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"age: Double\">age</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">39,856597</span></span>"] },
// { name: "<span title=\"fare: Double\">fare</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">332954,792813</span></span>"] },
// ], id: 1761607682, rootId: 1761607682, totalRows: 1 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(1761607682) });
//
//
//         </script>
//         </html>

// %%
df.count()
// Out:
// Executing:
// df.count()
// 1309

// %%
df.count { age != null }
// Out:
// Executing:
// df.count { age != null }
// 1046

// %%
df.count { it.age != null }
// Out:
// Executing:
// df.count { it.age != null }
// 1046

// %%
df.filter { age != null }
// Out:
// Executing:
// df.filter { age != null }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949441"></table>
//
// <p>... showing only top 20 of 1046 rows</p><p>DataFrame: rowsCount = 1046, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.drop { age != null }
// Out:
// Executing:
// df.drop { age != null }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949442"></table>
//
// <p>... showing only top 20 of 263 rows</p><p>DataFrame: rowsCount = 263, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.sortBy { name }
// Out:
// Executing:
// df.sortBy { name }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949443"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.sortBy { pclass and name }
// Out:
// Executing:
// df.sortBy { pclass and name }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949444"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.sortBy { pclass.desc() and name }
// Out:
// Executing:
// df.sortBy { pclass.desc() and name }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949445"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.sortBy { age }
// Out:
// Executing:
// df.sortBy { age }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949446"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.sortBy { age.nullsLast() }
// Out:
// Executing:
// df.sortBy { age.nullsLast() }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1509949447"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.update { name }
// Out:
// Executing:
// df.update { name }
// UpdateClause(df=    pclass survived                                     name    sex  age sibsp parch   ticket      fare   cabin embarked boat body                       home.dest
//   0      1        1            Allen, Miss. Elisabeth Walton female 29,0     0     0    24160 2113375,0      B5        S    2 null                    St Louis, MO
//   1      1        1           Allison, Master. Hudson Trevor   male 92,0     1     2   113781 1515500,0 C22 C26        S   11 null Montreal, PQ / Chesterville, ON
//   2      1        0             Allison, Miss. Helen Loraine female  2,0     1     2   113781 1515500,0 C22 C26        S null null Montreal, PQ / Chesterville, ON
//   3      1        0     Allison, Mr. Hudson Joshua Creighton   male 30,0     1     2   113781 1515500,0 C22 C26        S null  135 Montreal, PQ / Chesterville, ON
// ...

// %%
df.update { name }.with { it.uppercase() }
// Out:
// Executing:
// df.update { name }.with { it.uppercase() }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291201"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.update { name }.with { `home dest` }
// Out:
// Executing:
// df.update { name }.with { `home dest` }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291202"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.update { name }.with { name + " (" + age + ")" }
// Out:
// Executing:
// df.update { name }.with { name + " (" + age + ")" }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291203"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.update { name }.with { it + " (" + age + ")" }
// Out:
// Executing:
// df.update { name }.with { it + " (" + age + ")" }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291204"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.update { name }.where { sex == "male" }.with { it + " (" + age + ")" }
// Out:
// Executing:
// df.update { name }.where { sex == "male" }.with { it + " (" + age + ")" }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291205"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.update { name }.at(4,6,7).with { it + " (" + age + ")" }
// Out:
// Executing:
// df.update { name }.at(4,6,7).with { it + " (" + age + ")" }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291206"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.convert { survived }.with { it == 1 }
// Out:
// Executing:
// df.convert { survived }.with { it == 1 }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1258291207"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.add("lastName") { name.substringBefore(',') }
// Out:
// Executing:
// df.add("lastName") { name.substringBefore(',') }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410177"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 15</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.remove { name }
// Out:
// Executing:
// df.remove { name }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410178"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 13</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.remove { colsOf<String?>() }
// Out:
// Executing:
// df.remove { colsOf<String?>() }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410179"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 7</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.move { age }.to(2)
// Out:
// Executing:
// df.move { age }.to(2)
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410180"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.move { age }.after { survived }
// Out:
// Executing:
// df.move { age }.after { survived }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410181"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.move { age and fare }.after { survived }
// Out:
// Executing:
// df.move { age and fare }.after { survived }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410182"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.rename { survived }.into("alive")
// Out:
// Executing:
// df.rename { survived }.into("alive")
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1023410183"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.group { sibsp..body }.into {"details"}
// Out:
// Executing:
// df.group { sibsp..body }.into {"details"}
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1593835519"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 7</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
val grouped = df.group { sibsp..body }.into {"details"}
grouped
// Out:
// Executing:
// val grouped = df.group { sibsp..body }.into {"details"}
// grouped
// Executing:
// @DataSchema(isOpen = false)
// interface _DataFrameType2
//
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType2>.boat: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String?> @JvmName("_DataFrameType2_boat") get() = this["boat"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String?>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType2>.boat: kotlin.String? @JvmName("_DataFrameType2_boat") get() = this["boat"] as kotlin.String?
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType2>.body: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Int?> @JvmName("_DataFrameType2_body") get() = this["body"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Int?>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType2>.body: kotlin.Int? @JvmName("_DataFrameType2_body") get() = this["body"] as kotlin.Int?
// ...

// %%
grouped.details.sibsp
// Out:
// Executing:
// grouped.details.sibsp
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1593835517"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataColumn: name = "sibsp", type = Int, size = 1309</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
grouped.details
// Out:
// Executing:
// grouped.details
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1593835516"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>ColumnGroup: name = "details", rowsCount = 1309, columnsCount = 8</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
grouped.details.select { ticket and boat }
// Out:
// Executing:
// grouped.details.select { ticket and boat }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1593835515"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"ticket: String\">ticket</span>", children: [], rightAlign: false, values: ["24160","113781","113781","113781","113781","19952","13502","112050","11769","PC 17609","PC 17757","PC 17757","PC 17477","19877","27042","PC 17318","PC 17558","PC 17558","11813","13050"] },
// ...

// %%
grouped.details.max { boat }
// Out:
// Executing:
// grouped.details.max { boat }
// D

// %%
grouped.details.ticket[5]
// Out:
// Executing:
// grouped.details.ticket[5]
// 19952

// %%
grouped.details[5].ticket
// Out:
// Executing:
// grouped.details[5].ticket
// 19952

// %%
grouped.ungroup { details }
// Out:
// Executing:
// grouped.ungroup { details }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1593835514"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
grouped.flatten()
// Out:
// Executing:
// grouped.flatten()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1593835513"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }
// Out:
// Executing:
// df.split { name }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167169"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>Split</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",")
// Out:
// Executing:
// df.split { name }.by(",")
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167170"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>Split</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",").into("lastName", "firstName")
// Out:
// Executing:
// df.split { name }.by(",").into("lastName", "firstName")
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167171"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 15</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",", ".").into("lastName", "firstName")
// Out:
// Executing:
// df.split { name }.by(",", ".").into("lastName", "firstName")
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167172"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 17</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",", ".").into("lastName", "middleName", "firstName", "?")
// Out:
// Executing:
// df.split { name }.by(",", ".").into("lastName", "middleName", "firstName", "?")
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167174"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 17</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",", ".").inward("lastName", "middleName", "firstName", "?")
// Out:
// Executing:
// df.split { name }.by(",", ".").inward("lastName", "middleName", "firstName", "?")
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167175"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",", ".").inplace()
// Out:
// Executing:
// df.split { name }.by(",", ".").inplace()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167176"></table>
//
// <p>... showing only top 20 of 1309 rows</p><p>DataFrame: rowsCount = 1309, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
val splitted = df.split { name }.by(",", ".").inplace()
splitted
// Out:
// Executing:
// val splitted = df.split { name }.by(",", ".").inplace()
// splitted
// Executing:
// @DataSchema(isOpen = false)
// interface _DataFrameType1
//
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType1>.`home dest`: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String?> @JvmName("_DataFrameType1_home dest") get() = this["home.dest"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.String?>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType1>.`home dest`: kotlin.String? @JvmName("_DataFrameType1_home dest") get() = this["home.dest"] as kotlin.String?
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType1>.age: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double?> @JvmName("_DataFrameType1_age") get() = this["age"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double?>
// ...

// %%
splitted.explode { name }
// Out:
// Executing:
// splitted.explode { name }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167178"></table>
//
// <p>... showing only top 20 of 3928 rows</p><p>DataFrame: rowsCount = 3928, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
splitted.explode { name }.implode{name}
// Out:
// Executing:
// splitted.explode { name }.implode{name}
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167179"></table>
//
// <p>... showing only top 20 of 1288 rows</p><p>DataFrame: rowsCount = 1288, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.split { name }.by(",", ".").intoRows()
// Out:
// Executing:
// df.split { name }.by(",", ".").intoRows()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167180"></table>
//
// <p>... showing only top 20 of 3928 rows</p><p>DataFrame: rowsCount = 3928, columnsCount = 14</p>
//         </body>
//         <script>
//             /*<!--*/
// ...

// %%
df.groupBy { cabin }
// Out:
// Executing:
// df.groupBy { cabin }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167181"></table>
//
// <p>... showing only top 20 of 187 rows</p><p>GroupBy</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
df.groupBy { cabin }.count()
// Out:
// Executing:
// df.groupBy { cabin }.count()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167202"></table>
//
// <p>... showing only top 20 of 187 rows</p><p>DataFrame: rowsCount = 187, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
df.groupBy { cabin }.max { age }
// Out:
// Executing:
// df.groupBy { cabin }.max { age }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167203"></table>
//
// <p>... showing only top 20 of 187 rows</p><p>DataFrame: rowsCount = 187, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
df.groupBy { cabin }.maxFor { age and fare }
// Out:
// Executing:
// df.groupBy { cabin }.maxFor { age and fare }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167205"></table>
//
// <p>... showing only top 20 of 187 rows</p><p>DataFrame: rowsCount = 187, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
df.groupBy { cabin }.aggregate {
    count() into "count"
}
// Out:
// Executing:
// df.groupBy { cabin }.aggregate {
//     count() into "count"
// }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167206"></table>
//
// <p>... showing only top 20 of 187 rows</p><p>DataFrame: rowsCount = 187, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
df.groupBy { cabin }.aggregate {
    count() into "count"
    age.maxOrNull() into "maxAge"
}
// Out:
// Executing:
// df.groupBy { cabin }.aggregate {
//     count() into "count"
//     age.maxOrNull() into "maxAge"
// }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167207"></table>
//
// <p>... showing only top 20 of 187 rows</p><p>DataFrame: rowsCount = 187, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
val withAge = df.dropNulls { age }
// Out:
// Executing:
// val withAge = df.dropNulls { age }
// Executing:
// @DataSchema(isOpen = false)
// interface _DataFrameType2 : Line_5._DataFrameType
//
// val org.jetbrains.kotlinx.dataframe.ColumnsContainer<_DataFrameType2>.age: org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double> @JvmName("_DataFrameType2_age") get() = this["age"] as org.jetbrains.kotlinx.dataframe.DataColumn<kotlin.Double>
// val org.jetbrains.kotlinx.dataframe.DataRow<_DataFrameType2>.age: kotlin.Double @JvmName("_DataFrameType2_age") get() = this["age"] as kotlin.Double
// withAge.cast<_DataFrameType2>()
// Executing:
// val withAge = res29

// %%
withAge.groupBy { cabin }.aggregate {
    count() into "count"
    age.max() into "maxAge"
}
// Out:
// Executing:
// withAge.groupBy { cabin }.aggregate {
//     count() into "count"
//     age.max() into "maxAge"
// }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167211"></table>
//
// <p>... showing only top 20 of 175 rows</p><p>DataFrame: rowsCount = 175, columnsCount = 3</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
withAge.groupBy { cabin }.aggregate {
    count() into "count"
    age.max() into "maxAge"
    maxBy { age } into "oldest"
}
// Out:
// Executing:
// withAge.groupBy { cabin }.aggregate {
//     count() into "count"
//     age.max() into "maxAge"
//     maxBy { age } into "oldest"
// }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167210"></table>
//
// <p>... showing only top 20 of 175 rows</p><p>DataFrame: rowsCount = 175, columnsCount = 4</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
withAge.groupBy { cabin }.aggregate {
    count() into "count"
    age.max() into "maxAge"
    maxBy { age }.name into "oldest"
}
// Out:
// Executing:
// withAge.groupBy { cabin }.aggregate {
//     count() into "count"
//     age.max() into "maxAge"
//     maxBy { age }.name into "oldest"
// }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167212"></table>
//
// <p>... showing only top 20 of 175 rows</p><p>DataFrame: rowsCount = 175, columnsCount = 4</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cabin: String?\">cabin</span>", children: [], rightAlign: false, values: ["B5","C22 C26","E12","D7","A36","C101","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","C62 C64","B35","A23","B58 B60","D15","C6","D35","C148","C97","B49","C99","C52","T"] },
// ...

// %%
df.pivot { pclass }
// Out:
// Executing:
// df.pivot { pclass }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167213"></table>
//
// <p>Pivot</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"1: DataFrame\">1</span>", children: [], rightAlign: false, values: [{ frameId: 1644167214, value: "<b>DataFrame 323 x 14</b>" }] },
// { name: "<span title=\"2: DataFrame\">2</span>", children: [], rightAlign: false, values: [{ frameId: 1644167215, value: "<b>DataFrame 277 x 14</b>" }] },
// { name: "<span title=\"3: DataFrame\">3</span>", children: [], rightAlign: false, values: [{ frameId: 1644167216, value: "<b>DataFrame 709 x 14</b>" }] },
// ], id: 1644167213, rootId: 1644167213, totalRows: 1 } ) });
// /*-->*/
//
// /*<!--*/
// ...

// %%
df.pivot { pclass }.groupBy { embarked }
// Out:
// Executing:
// df.pivot { pclass }.groupBy { embarked }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167217"></table>
//
// <p>PivotGroupBy</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"embarked: String?\">embarked</span>", children: [], rightAlign: false, values: ["S","C","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","Q"] },
// { name: "<span title=\"1: DataFrame\">1</span>", children: [], rightAlign: false, values: [{ frameId: 1644167218, value: "<b>DataFrame 177 x 14</b>" },{ frameId: 1644167219, value: "<b>DataFrame 141 x 14</b>" },{ frameId: 1644167220, value: "<b>DataFrame 2 x 14</b>" },{ frameId: 1644167221, value: "<b>DataFrame 3 x 14</b>" }] },
// ...

// %%
df.pivot { pclass }.groupBy { embarked }.count()
// Out:
// Executing:
// df.pivot { pclass }.groupBy { embarked }.count()
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167228"></table>
//
// <p>DataFrame: rowsCount = 4, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"embarked: String?\">embarked</span>", children: [], rightAlign: false, values: ["S","C","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","Q"] },
// ...

// %%
df.pivot { pclass }.groupBy { embarked }.aggregate {
    count() into "count"
    maxBy(age).name into "oldest"
}
// Out:
// Executing:
// df.pivot { pclass }.groupBy { embarked }.aggregate {
//     count() into "count"
//     maxBy(age).name into "oldest"
// }
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_1644167229"></table>
//
// <p>DataFrame: rowsCount = 4, columnsCount = 2</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"embarked: String?\">embarked</span>", children: [], rightAlign: false, values: ["S","C","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","Q"] },
// ...
